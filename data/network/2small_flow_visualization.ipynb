# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('2small_network_flow.csv').astype(float)

# %%
fig = plt.figure(figsize=[16, 4])
ax1 = fig.add_subplot(111)
ax1.plot(range(180*8), data.iloc[0, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[1, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[2, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[3, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[4, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[5, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[6, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[7, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[8, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[9, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[10, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[11, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[12, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[13, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[14, 2:180*8+2])
ax1.plot(range(180*8), data.iloc[15, 2:180*8+2])
