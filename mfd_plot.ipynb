# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
q = pd.read_csv('q_20_aggragated.csv', index_col = 0)
b = pd.read_csv('b_20_aggragated.csv', index_col = 0)
v = pd.read_csv('v_20_aggragated.csv', index_col = 0)
b.head()
# Out:
#          2015-07-01 00:10:00  2015-07-01 00:20:00  2015-07-01 00:30:00  \
# HI2063a             3.006897                3.424             3.000000
# HI2063c             4.800000                5.800             5.600000
# HI2065a             0.000000                1.200             1.000000
# HI2065c             2.282759                2.296             2.400000
# HI2068a             4.914286                4.200             3.814286
#
#          2015-07-01 00:40:00  2015-07-01 00:50:00  2015-07-01 01:00:00  \
# HI2063a             2.600000             2.600000             2.800000
# HI2063c             4.800000             4.200000             3.400000
# HI2065a             0.364286             0.962963             0.592308
# HI2065c             2.000000             2.000000             1.600000
# HI2068a             4.200000             3.946154             3.875862
#
#          2015-07-01 01:10:00  2015-07-01 01:20:00  2015-07-01 01:30:00  \
# HI2063a                  2.4                  1.8                 2.00
# HI2063c                  3.6                  2.8                 2.60
# HI2065a                  0.2                  0.4                 0.20
# HI2065c                  1.8                  2.0                 1.60
# HI2068a                  3.2                  4.0                 3.55
#
#          2015-07-01 01:40:00  ...  2015-07-31 22:30:00  2015-07-31 22:40:00  \
# HI2063a             2.000000  ...            13.600000                8.040
# HI2063c             2.730769  ...             9.507143                7.600
# HI2065a             0.200000  ...             6.259259                4.600
# HI2065c             1.400000  ...             9.800000                7.728
# HI2068a             3.600000  ...             4.200000                4.000
#
#          2015-07-31 22:50:00  2015-07-31 23:00:00  2015-07-31 23:10:00  \
# HI2063a             7.154545             5.200000             6.203714
# HI2063c             9.023077             7.684615             8.115385
# HI2065a             3.200000             3.000000             3.600000
# HI2065c             6.727273             6.800000             6.031034
# HI2068a             4.800000             4.514023             4.248276
#
#          2015-07-31 23:20:00  2015-07-31 23:30:00  2015-07-31 23:40:00  \
# HI2063a             5.544000             5.872000             5.112000
# HI2063c             7.961538             9.433333             7.993915
# HI2065a             2.000000             2.200000             1.400000
# HI2065c             6.048000             5.680000             4.424000
# HI2068a             4.600000             4.200000             5.385185
#
#          2015-07-31 23:50:00  2015-08-01 00:00:00
# HI2063a             5.400000             3.312000
# HI2063c             6.642857             5.333333
# HI2065a             1.200000             1.400000
# HI2065c             4.600000             2.832000
# HI2068a             3.800000             3.390370
#
# [5 rows x 4464 columns]

# %%
q.mean().head()
# Out:
# 2015-07-01 00:10:00    220.311826
# 2015-07-01 00:20:00    212.496886
# 2015-07-01 00:30:00    198.966482
# 2015-07-01 00:40:00    190.451823
# 2015-07-01 00:50:00    182.390652
# dtype: float64

# %%
b.tail()
# Out:
#          2015-07-01 00:10:00  2015-07-01 00:20:00  2015-07-01 00:30:00  \
# HI9099c             9.591304             8.425397             9.896000
# HI9100a             3.600000             1.964286             2.177778
# HI9101c             3.400000             3.214286             3.177778
# HI9102a             2.078261             2.253455             2.007692
# HI9102c             5.045455             3.389130             5.170370
#
#          2015-07-01 00:40:00  2015-07-01 00:50:00  2015-07-01 01:00:00  \
# HI9099c            10.016667            11.000000             9.871429
# HI9100a             2.000000             1.288889             2.200000
# HI9101c             2.800000             2.703704             2.600000
# HI9102a             1.783333             1.800000             1.511111
# HI9102c             5.632000             6.000000             5.497846
#
#          2015-07-01 01:10:00  2015-07-01 01:20:00  2015-07-01 01:30:00  \
# HI9099c             9.766667             9.913043                8.868
# HI9100a             1.400000             1.600000                1.200
# HI9101c             2.800000             2.400000                2.000
# HI9102a             7.320000             1.690909                1.432
# HI9102c             4.175000             4.445455                4.864
#
#          2015-07-01 01:40:00  ...  2015-07-31 22:30:00  2015-07-31 22:40:00  \
# HI9099c            10.034783  ...             1.475000             1.530769
# HI9100a             1.000000  ...             5.800000             5.200000
# HI9101c             2.000000  ...             9.800000             6.400000
# HI9102a             1.130435  ...             7.308333             5.727273
# HI9102c             5.860870  ...             0.765217             0.904348
#
#          2015-07-31 22:50:00  2015-07-31 23:00:00  2015-07-31 23:10:00  \
# HI9099c                  1.0             1.530769             1.416667
# HI9100a                  6.0             4.400000             5.200000
# HI9101c                  7.6             5.800000             6.200000
# HI9102a                  6.4             4.923077             4.433333
# HI9102c                  0.4             0.530769             0.458333
#
#          2015-07-31 23:20:00  2015-07-31 23:30:00  2015-07-31 23:40:00  \
# HI9099c             1.515385             1.518182             1.316667
# HI9100a             4.800000             3.723077             3.600000
# HI9101c             5.200000             5.338462             4.400000
# HI9102a             4.192308             4.069565             3.816667
# HI9102c             0.515385             0.708333             0.330769
#
#          2015-07-31 23:50:00  2015-08-01 00:00:00
# HI9099c             1.481818             1.666667
# HI9100a             3.400000             2.703448
# HI9101c             4.800000             4.565517
# HI9102a             3.316667             3.291667
# HI9102c             1.466667             0.565217
#
# [5 rows x 4464 columns]

# %%
np.asarray(b).flatten()
# Out:
# array([3.00689655, 3.424     , 3.        , ..., 0.33076923, 1.46666667,
#        0.56521739])

# %%
plt.scatter(x = np.asarray(b).flatten(), y = np.asarray(q).flatten(), s=1)
plt.show()

# %%
plt.scatter(x = b.mean(), y = v.mean(), s=1)
plt.show()

# %%
id_class = pd.read_csv('id_402_withclass.csv')
id_class.head()
# Out:
#    Unnamed: 0       id        lat      long  num_road  class_i
# 0           0  HI7000d  116.42769  39.94485         4      0.0
# 1           1  HI7001a  116.42764  39.94330         3      0.0
# 2           2  HI7002a  116.42782  39.93705         2      0.0
# 3           3  HI7039a  116.42832  39.92993         3      0.0
# 4           4  HI7003a  116.42785  39.92513         3      0.0

# %%
rand_int = np.random.randint(0,402,50)
rand_int
# Out:
# array([297, 358, 334, 399, 200,  43, 249, 340, 346, 365, 134, 395, 220,
#          6, 148, 155,  98,   2, 115, 353,  90,  98,  55,  17, 126, 343,
#         66, 382, 276, 267,  24, 299,  66, 371, 101,  91, 110, 135, 289,
#        162, 389,  82,  30, 211, 285,   4,  81, 312, 181, 272])

# %%
for i in range(200):
    rand_int = np.random.randint(0,len(q),50)

    q_c0 = q.iloc[rand_int,:432]
    b_c0 = b.iloc[rand_int,:432]
    plt.scatter(x = b_c0.mean(), y = q_c0.mean(), s=1, c = 'b')

plt.show()

# %%
id_class0 = id_class[id_class.class_i == 0]
q_c0 = q.loc[id_class0.id]
b_c0 = b.loc[id_class0.id]

plt.scatter(x = b_c0.mean(), y = q_c0.mean(), s=1, c = 'b')
plt.show()

# %%
id_class0 = id_class[id_class.class_i == 0]
q_c0 = q.loc[id_class0.id]
b_c0 = b.loc[id_class0.id]

id_class0 = id_class[id_class.class_i == 1]
q_c1 = q.loc[id_class0.id]
b_c1 = b.loc[id_class0.id]

id_class0 = id_class[id_class.class_i == 2]
q_c2 = q.loc[id_class0.id]
b_c2 = b.loc[id_class0.id]

id_class0 = id_class[id_class.class_i == 3]
q_c3 = q.loc[id_class0.id]
b_c3 = b.loc[id_class0.id]

plt.scatter(x = b_c0.iloc[:,:432].mean(), y = q_c0.iloc[:,:432].mean(), s=1, c = 'b')


plt.scatter(x = b_c1.iloc[:,:432].mean(), y = q_c1.iloc[:,:432].mean(), s=1, c = 'g')

plt.scatter(x = b_c2.iloc[:,:432].mean(), y = q_c2.iloc[:,:432].mean(), s=1, c = 'y')

plt.scatter(x = b_c3.iloc[:,:432].mean(), y = q_c3.iloc[:,:432].mean(), s=1, c = 'black')

plt.show()

# %%
q_c2
# Out:
#          2015-07-01 00:10:00  2015-07-01 00:20:00  2015-07-01 00:30:00  \
# HI9001c           125.000000           132.366667           111.099130
# HI9002c            44.166667            41.000000            78.223333
# HI9003c            55.000000            43.821429            28.000000
# HI9004c           255.826087           247.000000           226.884615
# HI9005c           220.000000           205.000000           200.000000
# ...                      ...                  ...                  ...
# HI9053c           570.400000           541.000000           300.714286
# HI9054c           289.333333           320.000000           270.563607
# HI9055c           234.840000           235.000000           246.273752
# HI8020c           116.703704            69.000000            87.037037
# HI9079c           718.333333           845.000000           635.560000
#
#          2015-07-01 00:40:00  2015-07-01 00:50:00  2015-07-01 01:00:00  \
# HI9001c           115.000000           107.038462            80.000000
# HI9002c            99.652174            75.000000            79.029630
# HI9003c            24.000000            34.827586            25.000000
# HI9004c           213.260870           178.000000           210.371852
# HI9005c           167.000000           149.000000           150.000000
# ...                      ...                  ...                  ...
# HI9053c           273.678621           257.111111           236.000000
# HI9054c           294.833333           320.000000           268.861204
# HI9055c           274.875000           224.000000           273.469697
# HI8020c            83.035714            69.666667            82.907692
# HI9079c           740.640000           730.875000           625.920000
#
#          2015-07-01 01:10:00  2015-07-01 01:20:00  2015-07-01 01:30:00  \
# HI9001c            81.222222            99.653846            96.517241
# HI9002c            46.863636            75.500000            56.583333
# HI9003c            36.000000            29.000000            17.000000
# HI9004c           183.000000           154.478261           178.166667
# HI9005c           121.000000           127.000000           136.035714
# ...                      ...                  ...                  ...
# HI9053c           192.000000           203.821429           205.000000
# HI9054c           289.629630           320.000000           272.216667
# HI9055c           230.000000           170.000000           201.440000
# HI8020c            55.423077            69.440000            65.250000
# HI9079c           738.652174           741.545455           744.576923
#
#          2015-07-01 01:40:00  ...  2015-07-31 22:30:00  2015-07-31 22:40:00  \
# HI9001c            79.423077  ...            216.00000           236.000000
# HI9002c            64.440000  ...             80.00000            79.521739
# HI9003c            20.000000  ...             72.00000            81.000000
# HI9004c           154.230769  ...            460.12000           438.333333
# HI9005c           111.000000  ...            461.00000           453.000000
# ...                      ...  ...                  ...                  ...
# HI9053c           163.230769  ...            798.00000           711.000000
# HI9054c           294.280000  ...             45.00000            65.375000
# HI9055c           189.400000  ...            616.00000           583.041667
# HI8020c            68.440000  ...            318.00000           262.000000
# HI9079c           745.173913  ...            131.26087           118.083333
#
#          2015-07-31 22:50:00  2015-07-31 23:00:00  2015-07-31 23:10:00  \
# HI9001c           222.000000           224.000000           193.413793
# HI9002c            80.000000            80.750000            84.353043
# HI9003c            74.720000            58.000000            61.000000
# HI9004c           386.000000           383.625000           359.168696
# HI9005c           399.000000           390.000000           335.000000
# ...                      ...                  ...                  ...
# HI9053c           757.000000           706.310345           620.000000
# HI9054c            67.166667            45.000000            62.130435
# HI9055c           548.916667           491.000000           458.565217
# HI8020c           257.000000           214.000000           214.000000
# HI9079c           144.714286           105.000000           118.653846
#
#          2015-07-31 23:20:00  2015-07-31 23:30:00  2015-07-31 23:40:00  \
# HI9001c           230.000000           181.966667           195.000000
# HI9002c            85.555556            84.777778            83.212121
# HI9003c            66.000000            54.592593            57.888889
# HI9004c           333.357143           306.222222           324.838768
# HI9005c           336.000000           333.000000           349.000000
# ...                      ...                  ...                  ...
# HI9053c           574.000000           521.370370           519.758621
# HI9054c            45.000000            63.640000            61.625000
# HI9055c           431.000000           350.400000           331.708333
# HI8020c           198.000000           196.000000           191.275862
# HI9079c           114.800000           117.954545           118.086957
#
#          2015-07-31 23:50:00  2015-08-01 00:00:00
# HI9001c           164.206897           137.166667
# HI9002c            80.000000            79.083333
# HI9003c            51.000000            58.000000
# HI9004c           302.000000           272.960000
# HI9005c           307.000000           294.000000
# ...                      ...                  ...
# HI9053c           440.000000           392.370370
# HI9054c            45.000000            63.440000
# HI9055c           345.000000           330.807692
# HI8020c           173.000000           137.520000
# HI9079c           112.083333           111.000000
#
# [93 rows x 4464 columns]

# %%
id_class0 = id_class[id_class.class_i == 2]
q_c0 = q.loc[id_class0.id]
b_c0 = b.loc[id_class0.id]

plt.scatter(x = b_c0.mean(), y = q_c0.mean(), s=1)
plt.show()

# %%
id_class0 = id_class[id_class.class_i == 3]
q_c0 = q.loc[id_class0.id]
b_c0 = b.loc[id_class0.id]

plt.scatter(x = b_c0.mean(), y = q_c0.mean(), s=1)
plt.show()
